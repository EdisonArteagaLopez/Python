# %% [markdown]
# #Ejemplo listas

# %%
dias_de_la_semana = ["lunes", "martes", "miercoles", "jueves", "viernes", "sabado", "domingo"]
print (dias_de_la_semana)
# Out:
# ['lunes', 'martes', 'miercoles', 'jueves', 'viernes', 'sabado', 'domingo']

# %%
# Imprimir día miercoles

print (dias_de_la_semana[2])
# Out:
# miercoles

# %%
#Reemplazar un elemento

dias_de_la_semana [3] = "Daniela"
print (dias_de_la_semana)
# Out:
# ['lunes', 'martes', 'miercoles', 'Daniela', 'viernes', 'sabado', 'domingo']

# %%
# Sumar un elemento a la lista
dias_de_la_semana.append("Angie")
print(dias_de_la_semana)
# Out:
# ['lunes', 'martes', 'miercoles', 'Daniela', 'viernes', 'sabado', 'domingo', 'Angie']

# %%
#Borrar un elemento
dias_de_la_semana.remove("Daniela")
print(dias_de_la_semana)
# Out:
# ['lunes', 'martes', 'miercoles', 'viernes', 'sabado', 'domingo', 'Angie']

# %%
#Imprimir el ultimo elemento de la lista
print(dias_de_la_semana[6])
print(dias_de_la_semana[-2])
# Out:
# Angie
# domingo
