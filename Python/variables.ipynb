# %% [markdown]
# #Clase de declaración de variables

# %%
# Variable de tipo entero int

numero = 80
print (numero)
# Out:
# 80

# %%
# Variable tipo string str

color = ("Amarillo")
print(color)
# Out:
# Amarillo

# %%
# Variable tipo Flotante float

numero2 = 29.5
print (numero2)
# Out:
# 29.5

# %%
# Suma de variables

numero3= numero + 34
print (numero3)
# Out:
# 114

# %%
# multiplicación

numero4 = numero * numero3
print (numero4)
# Out:
# 9120
