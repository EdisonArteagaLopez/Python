# %% [markdown]
# # Análisis de Datos con el Dataset de Netflix
#
# En esta clase aprenderemos a realizar un análisis exploratorio de datos utilizando Pandas y Matplotlib con un dataset de títulos disponibles en Netflix.
#
# **Objetivos:**
# - Cargar y explorar un dataset real.
# - Realizar limpieza básica de datos.
# - Visualizar información relevante con gráficos.

# %%
# Paso 1: Importar librerías
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='whitegrid')

# %%
# Paso 2: Cargar el dataset desde una URL o archivo local
#Conectar drive
from google.colab import drive
drive.mount('/content/drive')

#Leer csv
df = pd.read_csv('/content/drive/MyDrive/Datasets/Netflix/netflix_titles.csv')
print ("Dataset cargado")

##df = pd.read_csv(netflix_url)
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Dataset cargado
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
# ...

# %%
# Paso 3: Exploración inicial de los datos
df.info()
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
#        show_id   type   title       director                cast  \
# count     8807   8807    8807           6173                7982
# unique    8807      2    8807           4528                7692
# ...

# %%
# Paso 4: Limpieza básica de datos
# Revisamos valores nulos
df.isnull().sum()
# Eliminamos columnas poco útiles si es necesario
# df = df.drop(columns=['show_id'])
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# Paso 5: Análisis de contenido
# Conteo por tipo (Movie o TV Show)
df['type'].value_counts().plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('Distribución de tipo de contenido en Netflix')
plt.ylabel('Cantidad')
plt.xlabel('Tipo')
plt.show()

# %%
# Paso 6: Contenido por país
top_countries = df['country'].value_counts().head(10)
top_countries.plot(kind='barh', color='purple')
plt.title('Top 10 países con más contenido en Netflix')
plt.xlabel('Número de títulos')
plt.show()

# %%
# Paso 7: Evolución temporal de contenido
df['date_added'] = pd.to_datetime(df['date_added'])
df['year_added'] = df['date_added'].dt.year
df['year_added'].value_counts().sort_index().plot(kind='line', marker='o')
plt.title('Cantidad de títulos añadidos por año')
plt.ylabel('Cantidad')
plt.xlabel('Año')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-a2aa73b61332> in <cell line: 0>()
#       1 # Paso 7: Evolución temporal de contenido
# ----> 2 df['date_added'] = pd.to_datetime(df['date_added'])
#       3 df['year_added'] = df['date_added'].dt.year
#       4 df['year_added'].value_counts().sort_index().plot(kind='line', marker='o')
#       5 plt.title('Cantidad de títulos añadidos por año')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061                 result = arg.tz_localize("utc")
#    1062     elif isinstance(arg, ABCSeries):
# -> 1063         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064         if not cache_array.empty:
#    1065             result = arg.map(cache_array)
#
# ...
